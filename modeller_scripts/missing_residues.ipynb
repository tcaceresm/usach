# %%
from modeller import *
from modeller.automodel import *
from modeller.parallel import Job, LocalWorker
import os
from loop_modelling_script import MyLoop

# %%
from modeller.automodel import LoopModel

# %%
print(os.getcwd())
# Out:
# /home/pc-usach-cm/Escritorio/tcaceres/estructura/MODELLER

# %%
code = '3v5e'

e = Environ()
m = Model(e, file=code)
aln = Alignment(e)
aln.append_model(m, align_codes=code)
aln.write(file=code+'.seq')

# %%
log.verbose()
env = Environ()

# directories for input atom files
env.io.atom_files_directory = ['.', '../atom_files']

a = LoopModel(env, alnfile = 'alignment.ali',
              knowns = '3v5e', sequence = '3v5e_fill')
a.starting_model= 1
a.ending_model  = 5

a.loop.starting_model = 1
a.loop.ending_model   = 1
a.loop.md_level       = refine.fast

a.make()

# %%
j = Job()
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())
j.append(LocalWorker())




log.verbose()
env = Environ()

env.io.atom_files_directory = ['.', '../atom_files']

# Create a new class based on 'LoopModel' so that we can redefine
# select_loop_atoms
#class MyLoop(LoopModel):
    # This routine picks the residues to be refined by loop modeling
  #  def select_loop_atoms(self):
  #      # Two residue ranges (both will be refined simultaneously)
  #      return Selection(self.residue_range('7:A', '12:A'),
 #                        self.residue_range('197:B', '202:B'),
#                         self.residue_range('387:C', '392:C'),
#                         self.residue_range('577:D', '582:D'),
#                         self.residue_range('767:E', '772:E'),
#                         self.residue_range('957:F', '962:F'),
#                         self.residue_range('1147:G', '1152:G'),
#                         self.residue_range('1337:H', '1342:H'),
#                         self.residue_range('1527:I', '1532:I'),
#                         self.residue_range('1717:J', '1722:J'),
#                         self.residue_range('1907:K', '1912:K'),
#                         self.residue_range('2097:L', '2192:L'),
#                         self.residue_range('2287:M', '2292:M'),
#                         self.residue_range('2477:N', '2482:N'),
#                         )

a = MyLoop(env,
           alnfile  = 'alignment.ali',      # alignment filename
           knowns   = '3v5e',               # codes of the templates
           sequence = '3v5e_fill',               # code of the target
           loop_assess_methods=assess.DOPE) # assess each loop with DOPE
a.starting_model= 1                 # index of the first model
a.ending_model  = 5                 # index of the last model

a.loop.starting_model = 1           # First loop model
a.loop.ending_model   = 2           # Last loop model

a.use_parallel_job(j)
a.make()
# Out:
# openf___224_> Open           $(LIB)/restyp.lib
# openf___224_> Open           ${MODINSTALL10v5}/modlib/resgrp.lib
# rdresgr_266_> Number of residue groups:        2
# openf___224_> Open           ${MODINSTALL10v5}/modlib/sstruc.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:    344838756  336756.594   328.864
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:    344839284  336757.125   328.864
# openf___224_> Open           ${MODINSTALL10v5}/modlib/resdih.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:    344887884  336804.562   328.911
# rdrdih__263_> Number of dihedral angle types         :        9
#               Maximal number of dihedral angle optima:        3
#               Dihedral angle names                   :  Alph Phi Psi Omeg chi1 chi2 chi3 chi4 chi5
# openf___224_> Open           ${MODINSTALL10v5}/modlib/radii.lib
#
# Dynamically allocated memory at   amaxlibraries [B,KiB,MiB]:    344901184  336817.562   328.923
# openf___224_> Open           ${MODINSTALL10v5}/modlib/af_mnchdef.lib
# rdwilmo_274_> Mainchain residue conformation classes:  APBLE
# openf___224_> Open           ${MODINSTALL10v5}/modlib/mnch.lib
# rdclass_257_> Number of classes:        5
# openf___224_> Open           ${MODINSTALL10v5}/modlib/mnch1.lib
# openf___224_> Open           ${MODINSTALL10v5}/modlib/mnch2.lib
# openf___224_> Open           ${MODINSTALL10v5}/modlib/mnch3.lib
# openf___224_> Open           ${MODINSTALL10v5}/modlib/xs4.mat
# rdrrwgh_268_> Number of residue types:       21
# openf___224_> Open           alignment.ali
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:    344913149  336829.250   328.935
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:    344914599  336830.656   328.936
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:    344917499  336833.500   328.939
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:    344923299  336839.156   328.944
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:    344934899  336850.500   328.956
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:    344958099  336873.156   328.978
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:    345004499  336918.469   329.022
#
# Dynamically allocated memory at   amaxalignment [B,KiB,MiB]:    345914907  337807.531   329.890
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345914935  337807.562   329.890
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345914963  337807.594   329.890
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345914991  337807.594   329.890
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915019  337807.625   329.890
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915047  337807.656   329.890
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915075  337807.688   329.890
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915103  337807.719   329.890
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915131  337807.750   329.890
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915159  337807.781   329.890
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915187  337807.812   329.890
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915215  337807.812   329.890
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915243  337807.844   329.890
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915271  337807.875   329.891
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915299  337807.906   329.891
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915327  337807.938   329.891
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915355  337807.969   329.891
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915383  337808.000   329.891
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915411  337808.031   329.891
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915439  337808.031   329.891
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915467  337808.062   329.891
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915495  337808.094   329.891
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915523  337808.125   329.891
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915551  337808.156   329.891
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915579  337808.188   329.891
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915607  337808.219   329.891
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345915635  337808.250   329.891
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345925935  337818.281   329.901
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    345936571  337828.688   329.911
#
# Read the alignment from file       : alignment.ali
#
# Total number of alignment positions:  2687
#
#   #  Code        #_Res #_Segm PDB_code    Name
# -------------------------------------------------------------------------------
#   1       3v5e    2576     14        3v5e MOL_ID  1; MOLECULE  ATP-DEPENDENT CLP PROTEASE PROTEOLYTIC SUBUNIT; CHAIN  A, B
#   2  3v5e_fill    2660     14
# check_a_343_> >> BEGINNING OF COMMAND
# openf___224_> Open           ./3v5e.pdb
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346711096  338585.062   330.649
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    346711096  338585.062   330.649
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346711267  338585.219   330.650
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346712117  338586.062   330.650
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346713375  338587.281   330.652
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346715279  338589.125   330.653
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346718135  338591.938   330.656
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    346718135  338591.938   330.656
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346718225  338592.031   330.656
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    346718225  338592.031   330.656
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346718360  338592.156   330.656
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346722644  338596.344   330.660
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    346722644  338596.344   330.660
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346722842  338596.531   330.661
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346729268  338602.812   330.667
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    346729268  338602.812   330.667
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346729565  338603.094   330.667
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346739187  338612.500   330.676
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    346739187  338612.500   330.676
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346739637  338612.938   330.677
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346754087  338627.031   330.690
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    346754087  338627.031   330.690
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346754762  338627.688   330.691
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346776420  338648.844   330.712
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    346776420  338648.844   330.712
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346776420  338648.844   330.712
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    346776420  338648.844   330.712
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346777428  338649.844   330.713
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346809932  338681.562   330.744
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    346809932  338681.562   330.744
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346811444  338683.062   330.745
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346860200  338730.656   330.792
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    346860200  338730.656   330.792
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346862468  338732.875   330.794
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346935602  338804.312   330.864
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    346935602  338804.312   330.864
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346935602  338804.312   330.864
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    346935602  338804.312   330.864
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    346939004  338807.625   330.867
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    347048688  338914.750   330.971
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    347048688  338914.750   330.971
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    347048688  338914.750   330.971
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    347048688  338914.750   330.971
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    347053791  338919.719   330.976
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    347218317  339080.375   331.133
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    347218317  339080.375   331.133
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    347218317  339080.375   331.133
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    347218317  339080.375   331.133
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    347225976  339087.875   331.141
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    347472782  339328.875   331.376
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    347472782  339328.875   331.376
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    347472782  339328.875   331.376
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    347472782  339328.875   331.376
#
# Dynamically allocated memory at amaxcoordinates [B,KiB,MiB]:    347484266  339340.094   331.387
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:    347472989  339329.094   331.376
#
# check_ali___> Checking the sequence-structure alignment.
#
# Implied intrachain target CA(i)-CA(i+1) distances longer than  8.0 angstroms:
#
# ALN_POS  TMPL  RID1  RID2  NAM1  NAM2     DIST
# ----------------------------------------------
# END OF TABLE
# check_a_344_> << END OF COMMAND
# openf___224_> Open           ${LIB}/top_heav.lib
# read_to_681_> topology.submodel read from topology file:        3
# openf___224_> Open           ${LIB}/par.lib
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:    347612241  339465.094   331.509
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:    347613841  339466.656   331.510
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:    347617821  339470.531   331.514
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:    347619821  339472.469   331.516
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:    347622821  339475.406   331.519
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:    347627321  339479.812   331.523
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:    347632893  339485.250   331.529
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:    347635693  339487.969   331.531
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:    347639893  339492.094   331.535
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:    347646193  339498.250   331.541
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:    347648965  339500.938   331.544
#
# Dynamically allocated memory at  amaxparameters [B,KiB,MiB]:    347650365  339502.312   331.545
# read_pa_232_> parameters    BONDS   ANGLS  DIHEDS IMPROPS    MODE
#                               227     561     661     112       0
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    347680038  339531.281   331.574
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    347825764  339673.594   331.712
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    347847212  339694.531   331.733
#
# mkilst______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      1      190   1468   1487      0         0       597
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    347908768  339754.656   331.792
#
# patch_______> segment topology patched using RTF:  1 ;  ILE  ;  NTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      1      190   1468   1487   2008      2343       597
#
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    347972784  339817.188   331.853
# patch_______> segment topology patched using RTF:  190 ;  GLU  ;  CTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      1      190   1469   1488   2010      2345       598
#
# genseg______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      1      190   1469   1488   2010      2345       598
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    347972812  339817.188   331.853
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    348002642  339846.344   331.881
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    348146604  339986.906   332.018
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    348168076  340007.875   332.039
#
# mkilst______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      2      380   2937   2975   2010      2345      1195
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    348229660  340068.031   332.098
#
# patch_______> segment topology patched using RTF:  191 ;  ILE  ;  NTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      2      380   2937   2975   4018      4688      1195
#
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    348298276  340135.031   332.163
# patch_______> segment topology patched using RTF:  380 ;  GLU  ;  CTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      2      380   2938   2976   4020      4690      1196
#
# genseg______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      2      380   2938   2976   4020      4690      1196
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    348298304  340135.062   332.163
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    348328134  340164.188   332.192
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    348472096  340304.781   332.329
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    348493568  340325.750   332.349
#
# mkilst______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      3      570   4406   4463   4020      4690      1793
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    348555152  340385.875   332.408
#
# patch_______> segment topology patched using RTF:  381 ;  ILE  ;  NTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      3      570   4406   4463   6028      7033      1793
#
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    348613488  340442.875   332.464
# patch_______> segment topology patched using RTF:  570 ;  GLU  ;  CTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      3      570   4407   4464   6030      7035      1794
#
# genseg______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      3      570   4407   4464   6030      7035      1794
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    348613516  340442.875   332.464
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    348643346  340472.031   332.492
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    348787308  340612.594   332.629
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    348808780  340633.562   332.650
#
# mkilst______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      4      760   5875   5951   6030      7035      2391
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    348870364  340693.719   332.709
#
# patch_______> segment topology patched using RTF:  571 ;  ILE  ;  NTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      4      760   5875   5951   8038      9378      2391
#
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    348954340  340775.719   332.789
# patch_______> segment topology patched using RTF:  760 ;  GLU  ;  CTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      4      760   5876   5952   8040      9380      2392
#
# genseg______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      4      760   5876   5952   8040      9380      2392
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    348954368  340775.750   332.789
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    348984198  340804.875   332.817
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    349128160  340945.469   332.955
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    349149632  340966.438   332.975
#
# mkilst______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      5      950   7344   7439   8040      9380      2989
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    349211216  341026.562   333.034
#
# patch_______> segment topology patched using RTF:  761 ;  ILE  ;  NTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      5      950   7344   7439  10048     11723      2989
#
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    349266192  341080.250   333.086
# patch_______> segment topology patched using RTF:  950 ;  GLU  ;  CTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      5      950   7345   7440  10050     11725      2990
#
# genseg______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      5      950   7345   7440  10050     11725      2990
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    349266220  341080.281   333.086
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    349296050  341109.438   333.115
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    349440012  341250.000   333.252
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    349461484  341270.969   333.272
#
# mkilst______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      6     1140   8813   8927  10050     11725      3587
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    349523068  341331.125   333.331
#
# patch_______> segment topology patched using RTF:  951 ;  ILE  ;  NTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      6     1140   8813   8927  12058     14068      3587
#
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    349589044  341395.562   333.394
# patch_______> segment topology patched using RTF:  1140 ;  GLU  ;  CTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      6     1140   8814   8928  12060     14070      3588
#
# genseg______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      6     1140   8814   8928  12060     14070      3588
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    349589072  341395.562   333.394
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    349618902  341424.719   333.423
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    349762864  341565.312   333.560
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    349788616  341590.438   333.584
#
# mkilst______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      7     1330  10282  10415  12060     14070      4185
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    349850200  341650.594   333.643
#
# patch_______> segment topology patched using RTF:  1141 ;  ILE  ;  NTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      7     1330  10282  10415  14068     16413      4185
#
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    349929336  341727.875   333.719
# patch_______> segment topology patched using RTF:  1330 ;  GLU  ;  CTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      7     1330  10283  10416  14070     16415      4186
#
# genseg______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      7     1330  10283  10416  14070     16415      4186
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    349929364  341727.906   333.719
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    349959194  341757.031   333.747
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    350103156  341897.625   333.884
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    350134068  341927.812   333.914
#
# mkilst______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      8     1520  11751  11903  14070     16415      4783
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    350195652  341987.938   333.973
#
# patch_______> segment topology patched using RTF:  1331 ;  ILE  ;  NTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      8     1520  11751  11903  16078     18758      4783
#
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    350290628  342080.688   334.063
# patch_______> segment topology patched using RTF:  1520 ;  GLU  ;  CTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      8     1520  11752  11904  16080     18760      4784
#
# genseg______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      8     1520  11752  11904  16080     18760      4784
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    350290656  342080.719   334.063
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    350320486  342109.844   334.092
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    350464448  342250.438   334.229
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    350501544  342286.656   334.264
#
# mkilst______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      9     1710  13220  13391  16080     18760      5381
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    350563128  342346.812   334.323
#
# patch_______> segment topology patched using RTF:  1521 ;  ILE  ;  NTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      9     1710  13220  13391  18088     21103      5381
#
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    350563184  342346.875   334.323
# patch_______> segment topology patched using RTF:  1710 ;  GLU  ;  CTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      9     1710  13221  13392  18090     21105      5382
#
# genseg______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                      9     1710  13221  13392  18090     21105      5382
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    350563212  342346.875   334.323
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    350593042  342376.031   334.352
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    350737004  342516.594   334.489
#
# mkilst______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     10     1900  14689  14879  18090     21105      5979
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    350798588  342576.750   334.548
#
# patch_______> segment topology patched using RTF:  1711 ;  ILE  ;  NTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     10     1900  14689  14879  20098     23448      5979
#
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    350912524  342688.000   334.656
# patch_______> segment topology patched using RTF:  1900 ;  GLU  ;  CTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     10     1900  14690  14880  20100     23450      5980
#
# genseg______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     10     1900  14690  14880  20100     23450      5980
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    350912552  342688.031   334.656
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    350942382  342717.156   334.685
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    351086344  342857.750   334.822
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    351130848  342901.219   334.864
#
# mkilst______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     11     2090  16158  16367  20100     23450      6577
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    351192432  342961.375   334.923
#
# patch_______> segment topology patched using RTF:  1901 ;  ILE  ;  NTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     11     2090  16158  16367  22108     25793      6577
#
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    351192488  342961.406   334.923
# patch_______> segment topology patched using RTF:  2090 ;  GLU  ;  CTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     11     2090  16159  16368  22110     25795      6578
#
# genseg______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     11     2090  16159  16368  22110     25795      6578
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    351192516  342961.438   334.923
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    351222346  342990.562   334.952
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    351366308  343131.156   335.089
#
# mkilst______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     12     2280  17627  17855  22110     25795      7175
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    351427892  343191.312   335.148
#
# patch_______> segment topology patched using RTF:  2091 ;  ILE  ;  NTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     12     2280  17627  17855  24118     28138      7175
#
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    351564628  343324.844   335.278
# patch_______> segment topology patched using RTF:  2280 ;  GLU  ;  CTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     12     2280  17628  17856  24120     28140      7176
#
# genseg______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     12     2280  17628  17856  24120     28140      7176
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    351564656  343324.875   335.278
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    351594486  343354.000   335.307
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    351738448  343494.562   335.444
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    351791856  343546.750   335.495
#
# mkilst______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     13     2470  19096  19343  24120     28140      7773
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    351853440  343606.875   335.554
#
# patch_______> segment topology patched using RTF:  2281 ;  ILE  ;  NTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     13     2470  19096  19343  26128     30483      7773
#
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    351853496  343606.938   335.554
# patch_______> segment topology patched using RTF:  2470 ;  GLU  ;  CTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     13     2470  19097  19344  26130     30485      7774
#
# genseg______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     13     2470  19097  19344  26130     30485      7774
#
# Dynamically allocated memory at    amaxsequence [B,KiB,MiB]:    351853524  343606.969   335.554
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    351883354  343636.094   335.582
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    352027316  343776.688   335.719
#
# mkilst______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     14     2660  20565  20831  26130     30485      8371
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    352088900  343836.812   335.778
#
# patch_______> segment topology patched using RTF:  2471 ;  ILE  ;  NTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     14     2660  20565  20831  28138     32828      8371
#
#
# Dynamically allocated memory at       amaxmodel [B,KiB,MiB]:    352252956  343997.031   335.935
# patch_______> segment topology patched using RTF:  2660 ;  GLU  ;  CTER
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     14     2660  20566  20832  28140     32830      8372
#
# genseg______> segment topology constructed from sequence and RTF:
#               segments residues  atoms  bonds angles dihedrals impropers:
#                     14     2660  20566  20832  28140     32830      8372
# transfe_506_> MODEL is an average of all templates.
# transfe_511_> Number of templates for coordinate transfer:        1
#               After transferring coordinates of the equivalent template atoms,
#               there are defined, undefined atoms in MODEL:    13985     6581
# openf___224_> Open           3v5e_fill.ini
# wrpdb___568_> Residues, atoms, selected atoms:     2660    20566    20566
# make_re_417_> Restraint type to be calculated:  stereo
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    352360405  344101.969   336.037
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    352368597  344109.969   336.045
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    352384981  344125.969   336.061
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    352417749  344157.969   336.092
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    352450517  344189.969   336.123
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    352516053  344253.969   336.186
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    352548821  344285.969   336.217
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    352614357  344349.969   336.279
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    352647125  344381.969   336.311
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    352778197  344509.969   336.436
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    352843733  344573.969   336.498
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    352974805  344701.969   336.623
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    353040341  344765.969   336.686
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    353302485  345021.969   336.936
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    353433557  345149.969   337.061
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    353695701  345405.969   337.311
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    353826773  345533.969   337.436
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    354351061  346045.969   337.936
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    354613205  346301.969   338.186
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    354875349  346557.969   338.436
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    355399637  347069.969   338.936
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    356448213  348093.969   339.936
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    356972501  348605.969   340.436
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    357496789  349117.969   340.936
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    358545365  350141.969   341.936
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    360642517  352189.969   343.936
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    361691093  353213.969   344.936
# r_stere_606_> Stereochemical restraints were constructed from RTF & PRMF.
#               Added bond,angle,dihedral,improper restraints  :    20832   28140   30954    8288
#               Total number of restraints before, now         :        0    88214
# make_re_422_> Number of previous, current restraints         :        0    88214
# make_re_423_> Number of previous, current selected restraints:        0    88214
# make_re_417_> Restraint type to be calculated:  phi-psi_binormal
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:    363211312  354698.562   346.385
# openf___224_> Open           ${MODINSTALL10v5}/modlib/mnch1.bin
# openf___224_> Open           ${MODINSTALL10v5}/modlib/mnch1.mdt
# getdata_643_> Protein accepted:  3v5e
# getdata_289_> Proteins (all/accepted):        1        1
# make_re_422_> Number of previous, current restraints         :    88214    90846
# make_re_423_> Number of previous, current selected restraints:    88214    90846
# make_re_417_> Restraint type to be calculated:  omega_dihedral
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:    363211328  354698.562   346.385
# openf___224_> Open           ${MODINSTALL10v5}/modlib/omega.bin
# openf___224_> Open           ${MODINSTALL10v5}/modlib/omega.mdt
# getdata_643_> Protein accepted:  3v5e
# getdata_289_> Proteins (all/accepted):        1        1
# omgdel__425_> Unselected all O C +N +CA dihedrals:     2730
#               (This is to avoid clashes between STEREO
#               and OMEGA_DIHEDRAL restraints)
# make_re_422_> Number of previous, current restraints         :    90846    93492
# make_re_423_> Number of previous, current selected restraints:    90846    90762
# make_re_417_> Restraint type to be calculated:  chi1_dihedral
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:    363211328  354698.562   346.385
# openf___224_> Open           ${MODINSTALL10v5}/modlib/chi1234.bin
# openf___224_> Open           ${MODINSTALL10v5}/modlib/chi1.mdt
# getdata_643_> Protein accepted:  3v5e
# getdata_289_> Proteins (all/accepted):        1        1
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    364259904  355722.562   347.385
# make_re_422_> Number of previous, current restraints         :    93492    95704
# make_re_423_> Number of previous, current selected restraints:    90762    92974
# make_re_417_> Restraint type to be calculated:  chi2_dihedral
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:    364259904  355722.562   347.385
# openf___224_> Open           ${MODINSTALL10v5}/modlib/chi1234.bin
# openf___224_> Open           ${MODINSTALL10v5}/modlib/chi2.mdt
# getdata_643_> Protein accepted:  3v5e
# getdata_289_> Proteins (all/accepted):        1        1
# make_re_422_> Number of previous, current restraints         :    95704    97482
# make_re_423_> Number of previous, current selected restraints:    92974    94752
# make_re_417_> Restraint type to be calculated:  chi3_dihedral
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:    364259904  355722.562   347.385
# openf___224_> Open           ${MODINSTALL10v5}/modlib/chi1234.bin
# openf___224_> Open           ${MODINSTALL10v5}/modlib/chi3.mdt
# getdata_643_> Protein accepted:  3v5e
# getdata_289_> Proteins (all/accepted):        1        1
# make_re_422_> Number of previous, current restraints         :    97482    98252
# make_re_423_> Number of previous, current selected restraints:    94752    95522
# make_re_417_> Restraint type to be calculated:  chi4_dihedral
#
# Dynamically allocated memory at   amaxstructure [B,KiB,MiB]:    364259904  355722.562   347.385
# openf___224_> Open           ${MODINSTALL10v5}/modlib/chi1234.bin
# openf___224_> Open           ${MODINSTALL10v5}/modlib/chi4.mdt
# mdtrsr__446W> A potential that relies on one protein is used, yet you have at
#               least one known structure available. MDT, not library, potential is used.
# getdata_643_> Protein accepted:  3v5e
# getdata_289_> Proteins (all/accepted):        1        1
# make_re_422_> Number of previous, current restraints         :    98252    98518
# make_re_423_> Number of previous, current selected restraints:    95522    95788
# make_re_417_> Restraint type to be calculated:  DISTANCE
#
# Dynamically allocated memory at amaxhash_contac [B,KiB,MiB]:    370182876  361506.719   353.034
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    372280028  363554.719   355.034
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    374377180  365602.719   357.034
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    378571484  369698.719   361.034
# make_re_422_> Number of previous, current restraints         :    98518   161470
# make_re_423_> Number of previous, current selected restraints:    95788   158740
# make_re_417_> Restraint type to be calculated:  DISTANCE
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    380668636  371746.719   363.034
# make_re_422_> Number of previous, current restraints         :   161470   223047
# make_re_423_> Number of previous, current selected restraints:   158740   220317
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :   223047   238656
# make_re_423_> Number of previous, current selected restraints:   220317   235926
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :   238656   240277
# make_re_423_> Number of previous, current selected restraints:   235926   237547
# 0 atoms in HETATM/BLK residues constrained
# to protein atoms within 2.30 angstroms
# and protein CA atoms within 10.00 angstroms
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :   240277   240277
# make_re_423_> Number of previous, current selected restraints:   237547   237547
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :   240277   240277
# make_re_423_> Number of previous, current selected restraints:   237547   237547
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :   240277   240277
# make_re_423_> Number of previous, current selected restraints:   237547   237547
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :   240277   240277
# make_re_423_> Number of previous, current selected restraints:   237547   237547
# 0 atoms in residues without defined topology
# constrained to be rigid bodies
# make_re_417_> Restraint type to be calculated:  DISTANCE
# make_re_422_> Number of previous, current restraints         :   240277   240277
# make_re_423_> Number of previous, current selected restraints:   237547   237547
# rmdupl__427_>    15988 redundant cosine dihedral restraints were unselected.
# condens_443_> Restraints marked for deletion were removed.
#               Total number of restraints before, now:   240277   221559
# openf___224_> Open           3v5e_fill.rsr
# openf___224_> Open           3v5e_fill.rsr
#
# Dynamically allocated memory at  amaxrestraints [B,KiB,MiB]:    380779482  371854.969   363.140
# rdcsr2__307_> Number of restraints read    :   221559
#               Number of excluded pairs read:        0
#               Number of pseudo atoms read  :        0
# rdcsrs__304_> Restraints in memory, selected restraints:   221559   221559
#               Explicitly excluded atom pairs in memory :        0
#               Pseudo atoms in memory                   :        0
# Running 5 tasks on 31 workers
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:0:ZWXLUIRN >& ipykernel_launcher.worker0
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:1:MQTZXXUO >& ipykernel_launcher.worker1
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:2:FJAMPFLW >& ipykernel_launcher.worker2
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:3:HFVGMRKE >& ipykernel_launcher.worker3
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:4:WTCSEMYR >& ipykernel_launcher.worker4
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:5:EMSFMFNO >& ipykernel_launcher.worker5
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:6:DRXFZKBB >& ipykernel_launcher.worker6
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:7:HNTCOVCB >& ipykernel_launcher.worker7
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:8:ZIGENUGA >& ipykernel_launcher.worker8
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:9:WDPPTNZS >& ipykernel_launcher.worker9
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:10:DHKCGMDC >& ipykernel_launcher.worker10
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:11:VHJUPIAT >& ipykernel_launcher.worker11
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:12:FYSZMCQP >& ipykernel_launcher.worker12
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:13:IVMKUTBB >& ipykernel_launcher.worker13
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:14:HIUBWOAI >& ipykernel_launcher.worker14
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:15:KPZSDXQP >& ipykernel_launcher.worker15
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:16:OQPXMIRK >& ipykernel_launcher.worker16
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:17:UOYPPXYG >& ipykernel_launcher.worker17
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:18:OCBOMJNE >& ipykernel_launcher.worker18
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:19:HIQJPJPN >& ipykernel_launcher.worker19
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:20:ZMDVSBUC >& ipykernel_launcher.worker20
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:21:ZIQJWTMC >& ipykernel_launcher.worker21
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:22:XZILJDGN >& ipykernel_launcher.worker22
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:23:RHMYYQZD >& ipykernel_launcher.worker23
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:24:AHGNPNMN >& ipykernel_launcher.worker24
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:25:FCQXKCTL >& ipykernel_launcher.worker25
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:26:XLPVHRBO >& ipykernel_launcher.worker26
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:27:QSIJVYAE >& ipykernel_launcher.worker27
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:28:WUEOXPSD >& ipykernel_launcher.worker28
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:29:ABZJTRDF >& ipykernel_launcher.worker29
# /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/bin/python /home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py -worker 127.0.1.1:58054:30:YDJNJCTD >& ipykernel_launcher.worker30
# Identified worker <Worker on localhost>
# Identified worker <Worker on localhost>
# Identified worker <Worker on localhost>
# Identified worker <Worker on localhost>
# Identified worker <Worker on localhost>
# Identified worker <Worker on localhost>
# ---------------------------------------------------------------------------
# RemoteError                               Traceback (most recent call last)
# Cell In[35], line 76
#      73 a.loop.ending_model   = 2           # Last loop model
#      75 a.use_parallel_job(j)
# ---> 76 a.make()
#
# File ~/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/automodel/loopmodel.py:42, in LoopModel.make(self, exit_stage)
#      40     self.build_seq(self.inimodel, 1)
#      41 else:
# ---> 42     AutoModel.make(self, exit_stage)
#      43 self.write_summary(self.loop.outputs, 'loop models')
#
# File ~/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/automodel/automodel.py:152, in AutoModel.make(self, exit_stage)
#     149 # getting model(s) (topology library must be in memory; ensured
#     150 # now by one of the three GENERATE_METHOD routines):
#     151 atmsel = self._check_select_atoms()
# --> 152 self.multiple_models(atmsel)
#     154 self.write_summary(self.outputs, 'models')
#     156 if self.final_malign3d:
#
# File ~/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/automodel/loopmodel.py:53, in LoopModel.multiple_models(self, atmsel)
#      51 def multiple_models(self, atmsel):
#      52     """Build all models, given the restraints and atom selection"""
# ---> 53     AutoModel.multiple_models(self, atmsel)
#      54     envcopy = self.env
#      55     self.env = self.loop.env
#
# File ~/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/automodel/automodel.py:256, in AutoModel.multiple_models(self, atmsel)
#     254 """Build all models, given all the previously generated restraints"""
#     255 if self.parallel_job is not None:
# --> 256     self.parallel_multiple_models(atmsel)
#     257 else:
#     258     for num in range(self.starting_model, self.ending_model + 1):
#
# File ~/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/automodel/automodel.py:276, in AutoModel.parallel_multiple_models(self, atmsel)
#     274 for num in range(self.starting_model, self.ending_model + 1):
#     275     job.queue_task(ModelTask(self, num, atmsel))
# --> 276 self.outputs.extend(job.run_all_tasks())
#
# File ~/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/job.py:178, in Job.run_all_tasks(self)
#     176 while True:
#     177     try:
# --> 178         for task in self._finish_all_tasks():
#     179             pass
#     180     except IndexError:
#
# File ~/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/job.py:211, in Job._finish_all_tasks(self)
#     209 else:
#     210     for obj in events:
# --> 211         task = self._process_event(obj, s)
#     212         if task:
#     213             yield task
#
# File ~/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/job.py:227, in Job._process_event(self, obj, listensock)
#     224 elif obj.running_task():
#     225     # A worker returned data
#     226     try:
# --> 227         task = obj.task_results()
#     228         if task:
#     229             # The worker completed its task
#     230             print("%s on %s completed" % (str(task), str(obj)))
#
# File ~/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/worker.py:63, in Worker.task_results(self)
#      61 """Read results from worker. If these terminate the task, return it."""
#      62 while True:
# ---> 63     r = self.get_data(allow_heartbeat=True)
#      64     self.update_contact_time()
#      65     # Allow for the case where both a heartbeat and task results are in
#      66     # the receive buffer:
#
# File ~/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/communicator.py:94, in Communicator.get_data(self, allow_heartbeat)
#      92 try:
#      93     while True:
# ---> 94         (cmdtype, obj) = self._recv()
#      95         if cmdtype == data_types.NetCommand:
#      96             self.__pending_commands.append(obj)
#
# File ~/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/communicator.py:135, in Communicator._recv(self)
#     133         raise obj.exc
#     134     else:
# --> 135         raise RemoteError(obj.exc, self)
#     136 elif isinstance(obj, data_types.TransferFile):
#     137     del obj  # file is already dumped automatically to disk
#
# RemoteError: <class 'AttributeError'>: Can't get attribute 'MyLoop' on <module '__main__' from '/home/pc-usach-cm/Documentos/miniconda3/envs/MODELLER/lib/python3.12/site-packages/modeller/parallel/modworker.py'> from <Worker on localhost>
